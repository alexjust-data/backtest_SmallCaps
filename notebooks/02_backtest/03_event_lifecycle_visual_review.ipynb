# %% [markdown]
# # 03 - Event Lifecycle Visual Review
# Notebook nuevo para revisar eventos con el widget 16H (stable v3).

# %%
# 03 - Loader visual 16H (stable v3)
from pathlib import Path

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\02_policy_integration\step16h_backside_dump_widget.py")
print(f"[03] Ejecutando: {SCRIPT}")

txt = SCRIPT.read_text(encoding="utf-8")
print(txt.splitlines()[1])  # Debe contener: stable v3

exec(txt, globals())
# Out:
# [03] Ejecutando: C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\02_policy_integration\step16h_backside_dump_widget.py
# # PASO 16H - BACKSIDE DUMP WIDGET (stable v3)
# 16H stable v3 loaded
# ### Paso 16H | run `step16e_event_lifecycle_20260226T192814Z`
# ...
# Output()
