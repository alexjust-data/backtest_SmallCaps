# %% [markdown]
# ## Ejemplo visual de los datos en files parker
#
# **Day Aggregates** : FALTA
# - S3: `us_stocks_sip/day_aggs_v1`
# - OHLCV diario por equity US.
# - local :
#
# **Minute Aggregates**
# - S3: `us_stocks_sip/minute_aggs_v1`
# - OHLCV por minuto.
# - local : `C:\TSIS_Data\data\ohlcv_intraday_1m\2004_2018\{ticker}\year=YYYY\month=MM\minute.parquet`

# %%
from pathlib import Path

# --- Controles de vista ---
HEAD_N = 5
TRANSPOSE = False                 # script 004 (foto parquet)

# --- 1) Foto del parquet minute ---
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\004_minute_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

# --- 2) Tabla de atributos + diccionario técnico ---
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\104_minute_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\ohlcv_intraday_1m\2004_2018\AACB\year=2004\month=01\minute.parquet
# rows: 312
# row_groups: 1
# columns: 12
#
# Schema literal:
# volume: int64
# vwap: double
# open: double
# close: double
# high: double
# low: double
# t: int64
# transactions: int64
# timestamp: timestamp[ms]
# ticker: large_string
# date: date32[day]
# minute: large_string
# year: dictionary<values=int32, indices=int32, ordered=0>
# month: dictionary<values=int32, indices=int32, ordered=0>
#
# Primeras 5 filas literales:
#    volume     vwap    open  close   high     low              t  transactions  \
# 0     400  15.2395  15.239  15.24  15.24  15.239  1073065980000             4
# 1     100  15.2100  15.210  15.21  15.21  15.210  1073066580000             1
# 2     100  15.1800  15.180  15.18  15.18  15.180  1073066640000             1
# 3     500  15.2420  15.190  15.32  15.32  15.190  1073066880000             3
# ...

# %% [markdown]
# **Trades (tick-level)**
# - S3: `us_stocks_sip/trades_v1`
# - Trades con timestamp ns.
# - local : `C:\TSIS_Data\data\trades_ticks_2004_2018\{ticker}\year=YYYY\month=MM\day=YYYY-MM-DD\market.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\005_market_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\105_market_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\trades_ticks_2004_2018\AACB\year=2004\month=01\day=2004-01-02\market.parquet
# rows: 19
# row_groups: 1
# columns: 5
#
# Schema literal:
# timestamp: int64
# price: double
# size: int64
# exchange: int64
# conditions: large_string
# year: dictionary<values=int32, indices=int32, ordered=0>
# month: dictionary<values=int32, indices=int32, ordered=0>
# day: dictionary<values=string, indices=int32, ordered=0>
#
# Primeras 5 filas literales:
#              timestamp  price  size  exchange conditions  year month  \
# 0  1073076695000000000  15.35   100         2             2004     1
# 1  1073076167000000000  15.35   100         2             2004     1
# 2  1073075838000000000  15.32   100        11             2004     1
# 3  1073074573000000000  15.30   100        11             2004     1
# 4  1073073790000000000  15.30   100        11             2004     1
#
#           day
# 0  2004-01-02
# 1  2004-01-02
# 2  2004-01-02
# 3  2004-01-02
# 4  2004-01-02
# ...

# %% [markdown]
# **Quotes (NBBO tick-level)**
# - S3: `us_stocks_sip/quotes_v1`
# - Top-of-book con timestamp ns.
# - local : `C:\TSIS_Data\data\quotes_p95\{ticker}\year=YYYY\month=MM\day=DD\quotes.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\006_quotes_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\106_quotes_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\quotes_p95\AABA\year=2019\month=01\day=02\quotes.parquet
# rows: 159598
# row_groups: 1
# columns: 12
#
# Schema literal:
# ask_exchange: int64
# ask_price: double
# ask_size: int64
# bid_exchange: int64
# bid_price: double
# bid_size: int64
# conditions: large_list<element: int64>
#   child 0, element: int64
# participant_timestamp: int64
# sequence_number: int64
# timestamp: int64
# tape: int64
# indicators: large_list<element: int64>
#   child 0, element: int64
# year: dictionary<values=int32, indices=int32, ordered=0>
# month: dictionary<values=int32, indices=int32, ordered=0>
# day: dictionary<values=int32, indices=int32, ordered=0>
#
# Primeras 5 filas literales:
#    ask_exchange  ask_price  ask_size  bid_exchange  bid_price  bid_size  \
# 0            18      57.17       200            15      56.33       700
# 1            12      57.17      1000            15      56.33       700
# ...

# %% [markdown]
# **Ticker Events**
# - REST: `reference/tickers/{id}/events`
# - Eventos de ticker (ticker_change, etc.).
# - local : `C:\TSIS_Data\data\additional\corporate_actions\ticker_events.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\009_ticker_events_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

from pathlib import Path
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\109_ticker_events_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\corporate_actions\ticker_events.parquet
# rows: 3766
# row_groups: 1
# columns: 4
#
# Schema literal:
# ticker: large_string
# ticker_change: struct<ticker: large_string>
#   child 0, ticker: large_string
# type: large_string
# date: large_string
#
# Primeras 5 filas literales:
#   ticker       ticker_change           type        date
# 0   AACB  {'ticker': 'AACB'}  ticker_change  2025-04-07
# 1   AAGR  {'ticker': 'AAGR'}  ticker_change  1969-12-31
# 2    AAM   {'ticker': 'AAM'}  ticker_change  2024-09-16
# 3   AAME  {'ticker': 'AAME'}  ticker_change  2003-09-10
# 4   AAMI  {'ticker': 'AAMI'}  ticker_change  2025-01-02
# Rango date: 1969-12-31 00:00:00 -> 2025-11-21 00:00:00
# FILE: C:\TSIS_Data\data\additional\corporate_actions\ticker_events.parquet
# rows: 3766
# row_groups: 1
# columns: 4
# ticker_events.parquet
#
# Diccionario tecnico de variables (oficial + mapeo local):
# {
#   "ticker": {
#     "definicion": "Simbolo del activo.",
# ...

# %% [markdown]
# **Splits**
# - REST: `reference/splits`
# - Corporate action (splits).
# - local : `C:\TSIS_Data\data\additional\corporate_actions\splits.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\007_splits_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\107_splits_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\corporate_actions\splits.parquet
# rows: 26812
# row_groups: 1
# columns: 5
#
# Schema literal:
# execution_date: large_string
# id: large_string
# split_from: double
# split_to: double
# ticker: large_string
#
# Primeras 5 filas literales:
#   execution_date                                                 id  \
# 0     2026-03-30  E0f5653c619604b99f1cb07e7a995b73f6ea613135f69c...
# 1     2026-01-06  E48e44b1448b773e7c07ddc880f3ff8323f5caf787d3d7...
# 2     2025-12-29  E557f0be1e36cd18048fb174008b033d565ec995d28f90...
# 3     2025-12-19  Efe0ea5c3ab2c315ffce9c42178fe887bd452f34588918...
# 4     2025-12-15  E6b5ce554540f3a217a0a7fcff9a62c1538c73a0e3f941...
#
#    split_from  split_to ticker
# 0         1.0      5.00  SGBKF
# 1         1.0     10.00  ITOCY
# 2         1.0      2.00  MBUMF
# 3         1.0      1.05   MLGF
# 4         1.0    100.00  INVMF
# Rango execution_date: 1978-10-25 00:00:00 -> 2026-03-30 00:00:00
# ...

# %% [markdown]
# **Dividends**
# - REST: `reference/dividends`
# - Corporate action (dividends).
# - local : `C:\TSIS_Data\data\additional\corporate_actions\dividends.parquet` (pendiente/no encontrado)

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\008_dividends_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\108_dividends_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE NOT FOUND: .

# %% [markdown]
# **Economic - Inflation**
# - Dataset macroecon?mico auxiliar.
# - local : `C:\TSIS_Data\data\additional\economic\inflation.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\010_inflation_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\110_inflation_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\economic\inflation.parquet
# rows: 261
# row_groups: 1
# columns: 7
#
# Schema literal:
# date: large_string
# cpi: double
# cpi_year_over_year: double
# cpi_core: double
# pce: double
# pce_core: double
# pce_spending: double
#
# Primeras 5 filas literales:
#          date    cpi  cpi_year_over_year  cpi_core     pce  pce_core  \
# 0  2004-01-01  186.3            1.926252     194.6  78.909    79.671
# 1  2004-02-01  186.7            1.693064     194.9  79.077    79.800
# 2  2004-03-01  187.1            1.737242     195.5  79.199    79.934
# 3  2004-04-01  187.4            2.285093     195.9  79.346    80.142
# 4  2004-05-01  188.2            3.051771     196.2  79.604    80.252
#
#    pce_spending
# 0        8007.1
# 1        8040.4
# 2        8098.8
# 3        8107.2
# 4        8176.5
# Rango date: 2004-01-01 00:00:00 -> 2025-09-01 00:00:00
# FILE: C:\TSIS_Data\data\additional\economic\inflation.parquet
# rows: 261
# row_groups: 1
# columns: 7
# ...

# %% [markdown]
# **Economic - Inflation Expectations**
# - Dataset macroecon?mico auxiliar.
# - local : `C:\TSIS_Data\data\additional\economic\inflation_expectations.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\011_inflation_expectations_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\111_inflation_expectations_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\economic\inflation_expectations.parquet
# rows: 262
# row_groups: 1
# columns: 8
#
# Schema literal:
# date: large_string
# market_5_year: double
# market_10_year: double
# forward_years_5_to_10: double
# model_1_year: double
# model_5_year: double
# model_10_year: double
# model_30_year: double
#
# Primeras 5 filas literales:
#          date  market_5_year  market_10_year  forward_years_5_to_10  \
# 0  2004-01-01           2.03            2.26                   2.49
# 1  2004-02-01           2.21            2.32                   2.43
# 2  2004-03-01           2.27            2.36                   2.45
# 3  2004-04-01           2.37            2.45                   2.53
# 4  2004-05-01           2.51            2.63                   2.75
#
#    model_1_year  model_5_year  model_10_year  model_30_year
# 0      1.906971      2.182070       2.316750       2.567783
# 1      1.987194      2.150390       2.275457       2.536252
# ...

# %% [markdown]
# **Economic - Treasury Yields**
# - Dataset macroecon?mico auxiliar.
# - local : `C:\TSIS_Data\data\additional\economic\treasury_yields.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\012_treasury_yields_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\112_treasury_yields_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\economic\treasury_yields.parquet
# rows: 5476
# row_groups: 1
# columns: 8
#
# Schema literal:
# date: large_string
# yield_1_month: double
# yield_3_month: double
# yield_1_year: double
# yield_2_year: double
# yield_5_year: double
# yield_10_year: double
# yield_30_year: double
#
# Primeras 5 filas literales:
#          date  yield_1_month  yield_3_month  yield_1_year  yield_2_year  \
# 0  2004-01-02           0.88           0.93          1.31          1.94
# 1  2004-01-05           0.88           0.91          1.35          1.95
# 2  2004-01-06           0.88           0.91          1.30          1.84
# 3  2004-01-07           0.88           0.91          1.29          1.84
# 4  2004-01-08           0.87           0.88          1.29          1.85
#
#    yield_5_year  yield_10_year  yield_30_year
# 0          3.36           4.38           5.30
# 1          3.39           4.41           5.28
# 2          3.26           4.29           5.26
# ...

# %% [markdown]
# **IPOs**
# - Dataset auxiliar de IPOs.
# - local : `C:\TSIS_Data\data\additional\ipos\all_ipos.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\013_all_ipos_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\113_all_ipos_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\ipos\all_ipos.parquet
# rows: 5247
# row_groups: 1
# columns: 14
#
# Schema literal:
# ticker: large_string
# name: large_string
# listing_date: large_string
# ipo_status: large_string
# security_type: large_string
# primary_exchange: large_string
# shares_offered: null
# price_range_low: null
# price_range_high: null
# final_price: double
# total_offer_size: double
# us_code: large_string
# isin: large_string
# currency: large_string
#
# Primeras 5 filas literales:
#   ticker                         name listing_date ipo_status security_type  \
# 0  CUYTY           Colruyt Group N.V.   2008-12-11    history          ADRC
# 1  VEMLY  Venture Corporation Limited   2009-01-09    history          ADRC
# 2  YELGY                     Hibu Plc   2009-02-10    history          ADRC
# 3  UCBJY                       UCB SA   2009-02-10    history          ADRC
# 4  TTHPY     TT Hellenic Postbank S.A   2009-02-10    history          ADRC
#
# ...

# %% [markdown]
# **Fundamentals - Balance Sheets**
# - REST: `reference/financials` (balance sheets)
# - local : `C:\TSIS_Data\data\fundamentals\balance_sheets\{ticker}.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\015_balance_sheets_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\115_balance_sheets_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\fundamentals\balance_sheets\AAC.parquet
# rows: 38
# row_groups: 1
# columns: 33
#
# Schema literal:
# tickers: large_list<element: large_string>
#   child 0, element: large_string
# cik: large_string
# period_end: large_string
# filing_date: large_string
# fiscal_quarter: int64
# fiscal_year: int64
# timeframe: large_string
# cash_and_equivalents: double
# receivables: double
# other_current_assets: double
# total_current_assets: double
# property_plant_equipment_net: double
# goodwill: double
# intangible_assets_net: double
# other_assets: double
# total_assets: double
# accounts_payable: double
# debt_current: double
# accrued_and_other_current_liabilities: double
# total_current_liabilities: double
# long_term_debt_and_capital_lease_obligations: double
# other_noncurrent_liabilities: double
# total_liabilities: double
# commitments_and_contingencies: double
# common_stock: double
# additional_paid_in_capital: double
# retained_earnings_deficit: double
# ...

# %% [markdown]
# **Fundamentals - Cash Flow Statements**
# - REST: `reference/financials` (cash flow)
# - local : `C:\TSIS_Data\data\fundamentals\cash_flow_statements\{ticker}.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\016_cash_flow_statements_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\116_cash_flow_statements_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\fundamentals\cash_flow_statements\AAC.parquet
# rows: 65
# row_groups: 1
# columns: 25
#
# Schema literal:
# tickers: large_list<element: large_string>
#   child 0, element: large_string
# cik: large_string
# period_end: large_string
# filing_date: large_string
# fiscal_quarter: int64
# fiscal_year: int64
# timeframe: large_string
# net_income: double
# depreciation_depletion_and_amortization: double
# other_operating_activities: double
# change_in_other_operating_assets_and_liabilities_net: double
# cash_from_operating_activities_continuing_operations: double
# net_cash_from_operating_activities: double
# purchase_of_property_plant_and_equipment: double
# other_investing_activities: double
# net_cash_from_investing_activities_continuing_operations: double
# net_cash_from_investing_activities: double
# short_term_debt_issuances_repayments: double
# long_term_debt_issuances_repayments: double
# dividends: double
# noncontrolling_interests: double
# ...

# %% [markdown]
# **Fundamentals - Income Statements**
# - REST: `reference/financials` (income statements)
# - local : `C:\TSIS_Data\data\fundamentals\income_statements\{ticker}.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\017_income_statements_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\117_income_statements_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\fundamentals\income_statements\AAC.parquet
# rows: 66
# row_groups: 1
# columns: 30
#
# Schema literal:
# tickers: large_list<element: large_string>
#   child 0, element: large_string
# cik: large_string
# period_end: large_string
# filing_date: large_string
# fiscal_quarter: int64
# fiscal_year: int64
# timeframe: large_string
# revenue: double
# cost_of_revenue: double
# gross_profit: double
# selling_general_administrative: double
# depreciation_depletion_amortization: double
# other_operating_expenses: double
# total_operating_expenses: double
# operating_income: double
# interest_expense: double
# other_income_expense: double
# total_other_income_expense: double
# income_before_income_taxes: double
# income_taxes: double
# consolidated_net_income_loss: double
# noncontrolling_interest: double
# preferred_stock_dividends_declared: double
# net_income_loss_attributable_common_shareholders: double
# basic_earnings_per_share: double
# ...

# %% [markdown]
# **Fundamentals - Smallcap Ratios**
# - Ratios derivados para small/micro caps.
# - local : `C:\TSIS_Data\data\fundamentals\smallcap_ratios\{ticker}.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\018_smallcap_ratios_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\118_smallcap_ratios_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\fundamentals\smallcap_ratios\AAC.parquet
# rows: 38
# row_groups: 1
# columns: 19
#
# Schema literal:
# ticker: null
# fiscal_period: null
# fiscal_year: int64
# end_date: null
# current_ratio: null
# quick_ratio: null
# cash_ratio: null
# quarterly_burn_rate: int64
# cash_runway_quarters: null
# debt_to_equity: double
# debt_to_assets: double
# gross_margin: null
# operating_margin: null
# net_margin: null
# roa: double
# roe: double
# bankruptcy_risk_flag: bool
# dilution_risk_flag: bool
# high_leverage_flag: bool
#
# Primeras 5 filas literales:
#   ticker fiscal_period  fiscal_year end_date current_ratio quick_ratio  \
# 0   None          None         2014     None          None        None
# 1   None          None         2014     None          None        None
# 2   None          None         2015     None          None        None
# 3   None          None         2015     None          None        None
# ...

# %% [markdown]
# **Fundamentals - Financial Ratios**
# - REST/derivado de financial ratios.
# - local : `C:\TSIS_Data\data\fundamentals\financial_ratios\{ticker}.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\019_financial_ratios_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\119_financial_ratios_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE NOT FOUND: C:\TSIS_Data\data\fundamentals\financial_ratios\AAC.parquet
# FILE NOT FOUND: C:\TSIS_Data\data\fundamentals\financial_ratios\AAC.parquet

# %% [markdown]
# **News**
# - REST: `stocks/news`
# - Noticias de stocks en batches.
# - local : `C:\TSIS_Data\data\additional\news\news_batch_0000.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\014_news_batch_0000_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\114_news_batch_0000_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\news\news_batch_0000.parquet
# rows: 5244
# row_groups: 1
# columns: 9
#
# Schema literal:
# ticker: large_string
# article_id: large_string
# title: large_string
# description: large_string
# published_utc: large_string
# article_url: large_string
# publisher_name: large_string
# tickers_mentioned: large_string
# keywords: large_string
#
# Primeras 5 filas literales:
#   ticker                                   article_id  \
# 0    AAC  w0gNOyy5_8Y1fNONHgY6PLIcl8b3dciHKQZikHM-KgU
# 1    AAC  Smyr2slA3_dn9xteXiYvCSX6MCYZ4MiAMbzKLwft0B4
# 2    AAC  XfnC3ZtdAMdoSkLlJLOXKu9mpJ8Fgr4QQShZpCL4bwQ
# 3    AAC  4gj0JxFOlJydx8hJ5QkNJBf7vC6-RqjNDnTVQxmcMPQ
# 4    AAC  k1YIxazi0j-DhXhJrVEgaaVzj0oeogtpQgSSR0my4dg
#
#                                                title  \
# 0    Rush Street Interactive: Asymmetric Risk Reward
# 1  Ares debuts second SPAC IPO in uncertain times...
# 2  British billionaire owner of Tottenham footbal...
# ...

# %% [markdown]
# **News**
# - REST: `stocks/news`
# - Noticias de stocks en batches.
# - local : `C:\TSIS_Data\data\additional\news\news_batch_0001.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\027_news_batch_0001_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\127_news_batch_0001_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\news\news_batch_0001.parquet
# rows: 4262
# row_groups: 1
# columns: 9
#
# Schema literal:
# ticker: large_string
# article_id: large_string
# title: large_string
# description: large_string
# published_utc: large_string
# article_url: large_string
# publisher_name: large_string
# tickers_mentioned: large_string
# keywords: large_string
#
# Primeras 5 filas literales:
#   ticker                                   article_id  \
# 0   ACRE  YiIgjoku4Cgyq2AY6T2ocytqyitF1sr5-axA1qgrPvg
# 1   ACRE  BIUARkqvkvdwr79g4kmyuIeMhLBzgGf664P3Edkf1ck
# 2   ACRE  g8VqVC5yZgfkzjYDjEG1lSatEbos4ERw59wgyZuKuTI
# 3   ACRE  Mgz053uF-yE_ZwBmC6qNhwNp8V275v6W8IOB0Kpj7co
# 4   ACRE  J4bEDIiI_fa9b396KS1_8rR_22svHPsM7TJ2emBNHw8
#
#                                                title  \
# 0  Ares Commercial Real Estate (ACRE) Q1 Earnings...
# 1                            Shortages Of Everything
# 2            Stocks That Hit 52-Week Highs On Monday
# ...

# %% [markdown]
# **News**
# - REST: `stocks/news`
# - Noticias de stocks en batches.
# - local : `C:\TSIS_Data\data\additional\news\news_batch_0002.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\028_news_batch_0002_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\128_news_batch_0002_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\additional\news\news_batch_0002.parquet
# rows: 4698
# row_groups: 1
# columns: 9
#
# Schema literal:
# ticker: large_string
# article_id: large_string
# title: large_string
# description: large_string
# published_utc: large_string
# article_url: large_string
# publisher_name: large_string
# tickers_mentioned: large_string
# keywords: large_string
#
# Primeras 5 filas literales:
#   ticker                                   article_id  \
# 0   AGCB  9UwjFxZeCYeDr2CEFjSQS5ZnqoxsxEOiE0DZSJq4qZk
# 1   AGCB  q4r4R2mgkEK_dpVwzkKemFMseOYswefinVKXbghprM0
# 2   AGCB  nxvHHSComnwxyBhLwle1B43eSu_jp91V3sDLeSaWpw4
# 3   AGEN  IQ-vQBXo6Ap5r7y_1BPG4u5oIsaFzacg0eAVJWZUraY
# 4   AGEN  v6_UrU583BZHYmuDeXKX1rSP7-HdZzKruzIvREztvXw
#
#                                                title  \
# 0  Tracking Seth Klarman's Baupost Group Holdings...
# 1  Tracking Seth Klarman's Baupost Group Holdings...
# 2  Tracking David Tepper's Appaloosa Management P...
# ...

# %% [markdown]
# **Technical Indicators (local sample)**
# - Exploraci?n de indicadores/r?gimen local.
# - local : `C:\TSIS_Data\data\regime_indicators\...\*.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\029_regime_indicators_sample_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\129_regime_indicators_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\regime_indicators\etfs\DIA\day.parquet
# rows: 5593
# row_groups: 1
# columns: 9
#
# Schema literal:
# volume: double
# vwap: double
# open: double
# close: double
# high: double
# low: double
# trades: int64
# datetime: timestamp[us]
# date: date32[day]
#
# Primeras 5 filas literales:
#       volume     vwap   open  close   high    low  trades  \
# 0  7632800.0  94.7619  95.09  94.68  95.25  94.21    8310
# 1  6202300.0  94.9356  94.74  94.97  95.34  94.53    6652
# 2  5045800.0  94.6200  94.55  95.05  95.20  94.10    6355
# 3  3837800.0  94.9655  95.13  94.83  95.21  94.25    5440
# 4  4996700.0  95.3914  94.95  96.00  96.05  94.91    5894
#
#                     datetime        date
# 0 1970-01-01 00:17:43.166400  1970-01-01
# 1 1970-01-01 00:17:43.252800  1970-01-01
# 2 1970-01-01 00:17:43.339200  1970-01-01
# 3 1970-01-01 00:17:43.598400  1970-01-01
# 4 1970-01-01 00:17:43.684800  1970-01-01
# Rango date: 1970-01-01 00:00:00 -> 1970-01-01 00:00:00
# ...

# %% [markdown]
# **Short Data - Short Interest**
# - Dataset de short interest.
# - local : `C:\TSIS_Data\data\short_data\short_interest\{ticker}.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\020_short_interest_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\120_short_interest_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\short_data\short_interest\AABA.parquet
# rows: 43
# row_groups: 1
# columns: 5
#
# Schema literal:
# settlement_date: large_string
# ticker: large_string
# short_interest: int64
# avg_daily_volume: int64
# days_to_cover: double
#
# Primeras 5 filas literales:
#   settlement_date ticker  short_interest  avg_daily_volume  days_to_cover
# 0      2017-12-29   AABA        23472187           9376655           2.50
# 1      2018-01-12   AABA        23750001           7991624           2.97
# 2      2018-01-31   AABA        28308876           8208679           3.45
# 3      2018-02-15   AABA        25431892           6378598           3.99
# 4      2018-02-28   AABA        24351969          10558499           2.31
# Rango settlement_date: 2017-12-29 00:00:00 -> 2019-09-30 00:00:00
# FILE: C:\TSIS_Data\data\short_data\short_interest\AABA.parquet
# rows: 43
# row_groups: 1
# columns: 5
# short_interest/AABA.parquet
#
# ...

# %% [markdown]
# **Short Data - Short Volume**
# - Dataset de short volume.
# - local : `C:\TSIS_Data\data\short_data\short_volume\{ticker}.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\021_short_volume_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\121_short_volume_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\short_data\short_volume\AACB.parquet
# rows: 109
# row_groups: 1
# columns: 20
#
# Schema literal:
# ticker: large_string
# date: large_string
# total_volume: int64
# short_volume: int64
# exempt_volume: int64
# non_exempt_volume: int64
# short_volume_ratio: double
# nyse_short_volume: int64
# nyse_short_volume_exempt: int64
# nasdaq_carteret_short_volume: int64
# nasdaq_carteret_short_volume_exempt: int64
# nasdaq_chicago_short_volume: int64
# nasdaq_chicago_short_volume_exempt: int64
# adf_short_volume: int64
# adf_short_volume_exempt: int64
# short_ratio: double
# exempt_ratio: int32
# short_ratio_ma5: double
# short_ratio_change: double
# short_ratio_zscore: double
#
# Primeras 5 filas literales:
#   ticker        date  total_volume  short_volume  exempt_volume  \
# 0   AACB  2025-04-07          2061           231              0
# 1   AACB  2025-04-08             2             2              0
# ...

# %% [markdown]
# **Reference - Condition Codes**
# - C?digos de condici?n de mercado.
# - local : `C:\TSIS_Data\data\reference\condition_codes.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\022_reference_condition_codes_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\122_reference_condition_codes_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\reference\condition_codes.parquet
# rows: 10
# row_groups: 1
# columns: 15
#
# Schema literal:
# id: int64
# type: large_string
# name: large_string
# asset_class: large_string
# sip_mapping: struct<CTA: large_string, UTP: large_string, FINRA_TDDS: large_string>
#   child 0, CTA: large_string
#   child 1, UTP: large_string
#   child 2, FINRA_TDDS: large_string
# update_rules: struct<consolidated: struct<updates_high_low: bool, updates_open_close: bool, updates_volume: bool>, (... 95 chars omitted)
#   child 0, consolidated: struct<updates_high_low: bool, updates_open_close: bool, updates_volume: bool>
#       child 0, updates_high_low: bool
#       child 1, updates_open_close: bool
#       child 2, updates_volume: bool
#   child 1, market_center: struct<updates_high_low: bool, updates_open_close: bool, updates_volume: bool>
#       child 0, updates_high_low: bool
#       child 1, updates_open_close: bool
#       child 2, updates_volume: bool
# ...

# %% [markdown]
# **Reference - Exchanges**
# - Cat?logo de exchanges.
# - local : `C:\TSIS_Data\data\reference\exchanges.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\023_reference_exchanges_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\123_reference_exchanges_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\reference\exchanges.parquet
# rows: 51
# row_groups: 1
# columns: 10
#
# Schema literal:
# id: int64
# type: large_string
# asset_class: large_string
# locale: large_string
# name: large_string
# acronym: large_string
# mic: large_string
# operating_mic: large_string
# participant_id: large_string
# url: large_string
#
# Primeras 5 filas literales:
#    id      type asset_class locale                                name  \
# 0   1  exchange      stocks     us                  NYSE American, LLC
# 1   2  exchange      stocks     us                 Nasdaq OMX BX, Inc.
# 2   3  exchange      stocks     us                 NYSE National, Inc.
# 3   4       TRF      stocks     us  FINRA Alternative Display Facility
# 4   5       SIP      stocks     us         Unlisted Trading Privileges
#
#   acronym   mic operating_mic participant_id  \
# 0    AMEX  XASE          XNYS              A
# 1     NaN  XBOS          XNAS              B
# ...

# %% [markdown]
# **Reference - Market Status Upcoming**
# - Estado/calendario pr?ximo de mercado.
# - local : `C:\TSIS_Data\data\reference\market_status_upcoming.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\024_reference_market_status_upcoming_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\124_reference_market_status_upcoming_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\reference\market_status_upcoming.parquet
# rows: 24
# row_groups: 1
# columns: 6
#
# Schema literal:
# date: large_string
# exchange: large_string
# name: large_string
# status: large_string
# close: large_string
# open: large_string
#
# Primeras 5 filas literales:
#          date exchange          name       status                     close  \
# 0  2025-11-27   NASDAQ  Thanksgiving       closed                       NaN
# 1  2025-11-27     NYSE  Thanksgiving       closed                       NaN
# 2  2025-11-28     NYSE  Thanksgiving  early-close  2025-11-28T18:00:00.000Z
# 3  2025-11-28   NASDAQ  Thanksgiving  early-close  2025-11-28T18:00:00.000Z
# 4  2025-12-24     NYSE     Christmas  early-close  2025-12-24T18:00:00.000Z
#
#                        open
# 0                       NaN
# 1                       NaN
# 2  2025-11-28T14:30:00.000Z
# 3  2025-11-28T14:30:00.000Z
# 4  2025-12-24T14:30:00.000Z
# ...

# %% [markdown]
# **Reference - Ticker Types**
# - Tipolog?as de ticker.
# - local : `C:\TSIS_Data\data\reference\ticker_types.parquet`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\025_reference_ticker_types_parquet2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())

SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\125_reference_ticker_types_attr_table.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# FILE: C:\TSIS_Data\data\reference\ticker_types.parquet
# rows: 25
# row_groups: 1
# columns: 4
#
# Schema literal:
# code: large_string
# description: large_string
# asset_class: large_string
# locale: large_string
#
# Primeras 5 filas literales:
#       code      description asset_class locale
# 0       CS     Common Stock      stocks     us
# 1      PFD  Preferred Stock      stocks     us
# 2  WARRANT          Warrant      stocks     us
# 3    RIGHT           Rights      stocks     us
# 4     BOND   Corporate Bond      stocks     us
# FILE: C:\TSIS_Data\data\reference\ticker_types.parquet
# rows: 25
# row_groups: 1
# columns: 4
# reference/ticker_types.parquet
#
# Diccionario tecnico de variables (oficial + mapeo local):
# {
#   "code": {
#     "definicion": "Campo 'code' presente en este parquet.",
#     "tipo_esperado": "large_string",
#     "origen_oficial": "Reference - Ticker Types",
#     "mapeo_api": "N/A",
# ...

# %% [markdown]
# ##  detecta en local qué objetivos Polygon clave faltan

# %% [markdown]
# **Audit - Polygon Targets Presence**
# - Revisi?n de objetivos Polygon presentes/faltantes en local.
# - local : `C:\TSIS_Data\data\...`

# %%
SCRIPT = Path(r"C:\TSIS_Data\v1\backtest_SmallCaps\notebooks\cell_code\00_data_certification\026_polygon_targets_presence2.py")
exec(SCRIPT.read_text(encoding="utf-8"), globals())
# Out:
# Polygon targets presence audit (max-plan scope, local evidence):
#                                  target                      polygon_scope  \
# 0         Corporate Actions - Dividends                Reference Dividends
# 1           Day Aggregates (flat files)          us_stocks_sip/day_aggs_v1
# 2        Second Aggregates (API/stream)  Stocks aggregates (1-second bars)
# 3                      Snapshots (REST)         Stocks snapshots endpoints
# 4            Corporate Actions - Splits                   Reference Splits
# 5                  Economic - Inflation                 Economic endpoints
# 6     Economic - Inflation Expectations                 Economic endpoints
# 7            Economic - Treasury Yields                 Economic endpoints
# 8         Fundamentals - Balance Sheets            Fundamentals statements
# 9   Fundamentals - Cash Flow Statements            Fundamentals statements
# 10     Fundamentals - Income Statements            Fundamentals statements
# ...
